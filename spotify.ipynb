# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# import pandas as pd
# import numpy as np
#
# # Load the dataset
# df = pd.read_csv('your_dataset.csv')
#
# # Remove rows with missing values
# df.dropna(inplace=True)
#
# # Remove duplicate rows
# df.drop_duplicates(inplace=True)
#
# # Convert data types
# df['column_name'] = df['column_name'].astype('int')
#
# # Remove leading and trailing whitespace
# df['column_name'] = df['column_name'].str.strip()
#
# # Replace values
# df['column_name'] = df['column_name'].str.replace('old_value', 'new_value')
#
# # Rename columns
# df.rename(columns={'old_name': 'new_name'}, inplace=True)
#
# # Display the cleaned DataFrame
# print(df.head())

# %%
spotify = pd.read_csv("Most Streamed Spotify Songs 2024.csv", encoding='ISO-8859-1')
spotify.head()
# Out:
#                         Track                    Album Name          Artist  \
# 0         MILLION DOLLAR BABY  Million Dollar Baby - Single   Tommy Richman
# 1                 Not Like Us                   Not Like Us  Kendrick Lamar
# 2  i like the way you kiss me    I like the way you kiss me         Artemas
# 3                     Flowers              Flowers - Single     Miley Cyrus
# 4                     Houdini                       Houdini          Eminem
#
#   Release Date          ISRC All Time Rank  Track Score Spotify Streams  \
# 0    4/26/2024  QM24S2402528             1        725.4     390,470,936
# 1     5/4/2024  USUG12400910             2        545.9     323,703,884
# 2    3/19/2024  QZJ842400387             3        538.4     601,309,283
# 3    1/12/2023  USSM12209777             4        444.9   2,031,280,633
# 4    5/31/2024  USUG12403398             5        423.3     107,034,922
#
#   Spotify Playlist Count Spotify Playlist Reach  ...  SiriusXM Spins  \
# ...

# %%
#to identify missinf values - isna()
#to count missing values in each columns - isna().sum()
spotify.isna()
spotify.isna().sum()
# Out:
# Track                            0
# Album Name                       0
# Artist                           5
# Release Date                     0
# ISRC                             0
# All Time Rank                    0
# Track Score                      0
# Spotify Streams                113
# Spotify Playlist Count          70
# Spotify Playlist Reach          72
# Spotify Popularity             804
# YouTube Views                  308
# YouTube Likes                  315
# TikTok Posts                  1173
# TikTok Likes                   980
# TikTok Views                   981
# YouTube Playlist Reach        1009
# Apple Music Playlist Count     561
# AirPlay Spins                  498
# SiriusXM Spins                2123
# Deezer Playlist Count          921
# Deezer Playlist Reach          928
# Amazon Playlist Count         1055
# Pandora Streams               1106
# Pandora Track Stations        1268
# Soundcloud Streams            3333
# Shazam Counts                  577
# ...

# %%
spotify.columns
# Out:
# Index(['Track', 'Album Name', 'Artist', 'Release Date', 'ISRC',
#        'All Time Rank', 'Track Score', 'Spotify Streams',
#        'Spotify Playlist Count', 'Spotify Playlist Reach',
#        'Spotify Popularity', 'YouTube Views', 'YouTube Likes', 'TikTok Posts',
#        'TikTok Likes', 'TikTok Views', 'YouTube Playlist Reach',
#        'Apple Music Playlist Count', 'AirPlay Spins', 'SiriusXM Spins',
#        'Deezer Playlist Count', 'Deezer Playlist Reach',
#        'Amazon Playlist Count', 'Pandora Streams', 'Pandora Track Stations',
#        'Soundcloud Streams', 'Shazam Counts', 'TIDAL Popularity',
#        'Explicit Track'],
#       dtype='object')

# %%
spotify.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 29 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Track                       4600 non-null   object
#  1   Album Name                  4600 non-null   object
#  2   Artist                      4595 non-null   object
#  3   Release Date                4600 non-null   object
#  4   ISRC                        4600 non-null   object
#  5   All Time Rank               4600 non-null   object
#  6   Track Score                 4600 non-null   float64
#  7   Spotify Streams             4487 non-null   object
#  8   Spotify Playlist Count      4530 non-null   object
#  9   Spotify Playlist Reach      4528 non-null   object
#  10  Spotify Popularity          3796 non-null   float64
#  11  YouTube Views               4292 non-null   object
#  12  YouTube Likes               4285 non-null   object
# ...

# %%
# to visualize missing values

# %%
pip install missingno
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import missingno as msno

# %%
#to visualize missing values using msno matrix
msno.matrix(spotify)
plt.show()

# %%
spotify.shape
# Out:
# (4600, 29)

# %%
spotify.size
# Out:
# 133400

# %%
spotify.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 29 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Track                       4600 non-null   object
#  1   Album Name                  4600 non-null   object
#  2   Artist                      4595 non-null   object
#  3   Release Date                4600 non-null   object
#  4   ISRC                        4600 non-null   object
#  5   All Time Rank               4600 non-null   object
#  6   Track Score                 4600 non-null   float64
#  7   Spotify Streams             4487 non-null   object
#  8   Spotify Playlist Count      4530 non-null   object
#  9   Spotify Playlist Reach      4528 non-null   object
#  10  Spotify Popularity          3796 non-null   float64
#  11  YouTube Views               4292 non-null   object
#  12  YouTube Likes               4285 non-null   object
# ...

# %%
spotify.dtypes
# Out:
# Track                          object
# Album Name                     object
# Artist                         object
# Release Date                   object
# ISRC                           object
# All Time Rank                  object
# Track Score                   float64
# Spotify Streams                object
# Spotify Playlist Count         object
# Spotify Playlist Reach         object
# Spotify Popularity            float64
# YouTube Views                  object
# YouTube Likes                  object
# TikTok Posts                   object
# TikTok Likes                   object
# TikTok Views                   object
# YouTube Playlist Reach         object
# Apple Music Playlist Count    float64
# AirPlay Spins                  object
# SiriusXM Spins                 object
# Deezer Playlist Count         float64
# Deezer Playlist Reach          object
# Amazon Playlist Count         float64
# Pandora Streams                object
# Pandora Track Stations         object
# ...

# %%
spotify.head()
# Out:
#                         Track                    Album Name          Artist  \
# 0         MILLION DOLLAR BABY  Million Dollar Baby - Single   Tommy Richman
# 1                 Not Like Us                   Not Like Us  Kendrick Lamar
# 2  i like the way you kiss me    I like the way you kiss me         Artemas
# 3                     Flowers              Flowers - Single     Miley Cyrus
# 4                     Houdini                       Houdini          Eminem
#
#   Release Date          ISRC All Time Rank  Track Score Spotify Streams  \
# 0    4/26/2024  QM24S2402528             1        725.4     390,470,936
# 1     5/4/2024  USUG12400910             2        545.9     323,703,884
# 2    3/19/2024  QZJ842400387             3        538.4     601,309,283
# 3    1/12/2023  USSM12209777             4        444.9   2,031,280,633
# 4    5/31/2024  USUG12403398             5        423.3     107,034,922
#
#   Spotify Playlist Count Spotify Playlist Reach  ...  SiriusXM Spins  \
# ...

# %%
spotify.describe()
# Out:
#        Track Score  Spotify Popularity  Apple Music Playlist Count  \
# count  4600.000000         3796.000000                  4039.00000
# mean     41.844043           63.501581                    54.60312
# std      38.543766           16.186438                    71.61227
# min      19.400000            1.000000                     1.00000
# 25%      23.300000           61.000000                    10.00000
# 50%      29.900000           67.000000                    28.00000
# 75%      44.425000           73.000000                    70.00000
# max     725.400000           96.000000                   859.00000
#
#        Deezer Playlist Count  Amazon Playlist Count  TIDAL Popularity  \
# count            3679.000000            3545.000000               0.0
# mean               32.310954              25.348942               NaN
# std                54.274538              25.989826               NaN
# min                 1.000000               1.000000               NaN
# ...

# %%
duplicated_rows = spotify.duplicated().sum()
print(f"Number of duplicated rows: {duplicated_rows}")
# Out:
# Number of duplicated rows: 2

# %%
missing_rows = spotify.isna().sum()
missing_rows
# Out:
# Track                            0
# Album Name                       0
# Artist                           5
# Release Date                     0
# ISRC                             0
# All Time Rank                    0
# Track Score                      0
# Spotify Streams                113
# Spotify Playlist Count          70
# Spotify Playlist Reach          72
# Spotify Popularity             804
# YouTube Views                  308
# YouTube Likes                  315
# TikTok Posts                  1173
# TikTok Likes                   980
# TikTok Views                   981
# YouTube Playlist Reach        1009
# Apple Music Playlist Count     561
# AirPlay Spins                  498
# SiriusXM Spins                2123
# Deezer Playlist Count          921
# Deezer Playlist Reach          928
# Amazon Playlist Count         1055
# Pandora Streams               1106
# Pandora Track Stations        1268
# Soundcloud Streams            3333
# Shazam Counts                  577
# ...

# %% [markdown]
# #Fill the missing values

# %%
spotify['Spotify Streams'].fillna('0', inplace =True)
spotify['Artist'].fillna('-',inplace=True)
spotify['Spotify Playlist Count'].fillna('0', inplace =True)
spotify['Spotify Playlist Reach'].fillna('0', inplace =True)
spotify['Spotify Popularity'].fillna('0', inplace =True)
spotify['YouTube Views'].fillna('0', inplace =True)
spotify['YouTube Likes'].fillna('0', inplace = True)
spotify['TikTok Posts'].fillna('0', inplace = True)
spotify['TikTok Likes'].fillna('0', inplace = True)
spotify['TikTok Views'].fillna('0', inplace =True)
spotify['YouTube Playlist Reach'].fillna('-',inplace=True)
spotify['Apple Music Playlist Count'].fillna('0', inplace =True)
spotify['AirPlay Spins'].fillna('0', inplace =True)
spotify['SiriusXM Spins'].fillna('0', inplace =True)
spotify['Deezer Playlist Count'].fillna('0', inplace =True)
spotify['Deezer Playlist Reach'].fillna('0', inplace = True)
spotify['Amazon Playlist Count'].fillna('0', inplace = True)
spotify['Pandora Streams'].fillna('0', inplace = True)
spotify['Pandora Track Stations'].fillna('0', inplace =True)
spotify['Soundcloud Streams'].fillna('0', inplace = True)
spotify['Shazam Counts'].fillna('0', inplace = True)
spotify['TIDAL Popularity'].fillna('0', inplace = True)

# %%
spotify.isna().sum()
# Out:
# Track                         0
# Album Name                    0
# Artist                        0
# Release Date                  0
# ISRC                          0
# All Time Rank                 0
# Track Score                   0
# Spotify Streams               0
# Spotify Playlist Count        0
# Spotify Playlist Reach        0
# Spotify Popularity            0
# YouTube Views                 0
# YouTube Likes                 0
# TikTok Posts                  0
# TikTok Likes                  0
# TikTok Views                  0
# YouTube Playlist Reach        0
# Apple Music Playlist Count    0
# AirPlay Spins                 0
# SiriusXM Spins                0
# Deezer Playlist Count         0
# Deezer Playlist Reach         0
# Amazon Playlist Count         0
# Pandora Streams               0
# Pandora Track Stations        0
# Soundcloud Streams            0
# Shazam Counts                 0
# TIDAL Popularity              0
# Explicit Track                0
# ...

# %%
spotify.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 29 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Track                       4600 non-null   object
#  1   Album Name                  4600 non-null   object
#  2   Artist                      4600 non-null   object
#  3   Release Date                4600 non-null   object
#  4   ISRC                        4600 non-null   object
#  5   All Time Rank               4600 non-null   object
#  6   Track Score                 4600 non-null   float64
#  7   Spotify Streams             4600 non-null   object
#  8   Spotify Playlist Count      4600 non-null   object
#  9   Spotify Playlist Reach      4600 non-null   object
#  10  Spotify Popularity          4600 non-null   object
#  11  YouTube Views               4600 non-null   object
#  12  YouTube Likes               4600 non-null   object
# ...

# %% [markdown]
# # Datatype conversion

# %%
spotify['Release Date'] = pd.to_datetime(spotify['Release Date'])
spotify['Spotify Streams'] = pd.to_numeric(spotify['Spotify Streams'], errors ='coerce')
spotify['All Time Rank'] = pd.to_numeric(spotify['All Time Rank'], downcast='integer', errors ='coerce')
spotify['Spotify Playlist Count'] = pd.to_numeric(spotify['Spotify Playlist Count'],downcast='integer',errors='coerce')
spotify['Spotify Playlist Reach'] = pd.to_numeric(spotify['Spotify Playlist Reach'], errors = 'coerce')
spotify['Spotify Popularity'] = pd.to_numeric(spotify['Spotify Popularity'], downcast='integer', errors ='coerce')
spotify['YouTube Views'] = pd.to_numeric(spotify['YouTube Views'], errors ='coerce')
spotify['YouTube Likes'] = pd.to_numeric(spotify['YouTube Likes'], downcast='integer', errors ='coerce')
spotify['TikTok Posts'] = pd.to_numeric(spotify['TikTok Posts'],downcast='integer',errors='coerce')
spotify['TikTok Likes'] = pd.to_numeric(spotify['TikTok Likes'], errors = 'coerce')
spotify['TikTok Views'] = pd.to_numeric(spotify['TikTok Views'], downcast='integer', errors ='coerce')
spotify['YouTube Playlist Reach'] = pd.to_numeric(spotify['YouTube Playlist Reach'], errors ='coerce')
spotify['Apple Music Playlist Count'] = pd.to_numeric(spotify['Apple Music Playlist Count'], downcast='integer', errors ='coerce')
spotify['AirPlay Spins'] = pd.to_numeric(spotify['AirPlay Spins'],downcast='integer',errors='coerce')
spotify['SiriusXM Spins'] = pd.to_numeric(spotify['SiriusXM Spins'], errors = 'coerce')
spotify['Deezer Playlist Count'] = pd.to_numeric(spotify['Deezer Playlist Count'], downcast='integer', errors ='coerce')
spotify['Deezer Playlist Reach'] = pd.to_numeric(spotify['Deezer Playlist Reach'], errors ='coerce')
spotify['Soundcloud Streams'] = pd.to_numeric(spotify['Soundcloud Streams'], downcast='integer', errors ='coerce')
spotify['Pandora Streams'] = pd.to_numeric(spotify['Pandora Streams'],downcast='integer',errors='coerce')
spotify['Pandora Track Stations'] = pd.to_numeric(spotify['Pandora Track Stations'], errors = 'coerce')
spotify['Amazon Playlist Count'] = pd.to_numeric(spotify['Amazon Playlist Count'], downcast='integer', errors ='coerce')
spotify['Shazam Counts'] = pd.to_numeric(spotify['Shazam Counts'], errors = 'coerce')
spotify['TIDAL Popularity'] = pd.to_numeric(spotify['TIDAL Popularity'], downcast='integer', errors ='coerce')

# %%
spotify.dtypes
# Out:
# Track                                 object
# Album Name                            object
# Artist                                object
# Release Date                  datetime64[ns]
# ISRC                                  object
# All Time Rank                          Int16
# Track Score                          float64
# Spotify Streams                      float64
# Spotify Playlist Count               float64
# Spotify Playlist Reach               float64
# Spotify Popularity                      int8
# YouTube Views                        float64
# YouTube Likes                        float64
# TikTok Posts                         float64
# TikTok Likes                         float64
# TikTok Views                         float64
# YouTube Playlist Reach               float64
# Apple Music Playlist Count             int16
# AirPlay Spins                        float64
# SiriusXM Spins                       float64
# Deezer Playlist Count                  int16
# ...
